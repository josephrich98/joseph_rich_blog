# %% [markdown]
# <a href="https://colab.research.google.com/github/josephrich98/joseph_rich_blog/blob/main/posts/post1/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    # !pip install numpy==2.2.6 pandas==2.2.3 matplotlib==3.10.3 scipy==1.15.3 scanpy==1.11.1 seaborn==0.13.2

# %%
import os

# %%
print("hello")
# Out:
# hello

# %%
print("hello2")
# Out:
# hello2
